# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read CSV file

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Colleague;Friend or family member;Other online...
# 4  Books / Physical media;Online Courses or Certi...
#
#                                      LearnCodeOnline  ...        Frequency_1  \
# 0                                                NaN  ...                NaN
# 1  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 2  Formal documentation provided by the owner of ...  ...  6-10 times a week
# 3  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 4  Formal documentation provided by the owner of ...  ...   1-2 times a week
#
#          Frequency_2       Frequency_3         TimeSearching  \
# 0                NaN               NaN                   NaN
# 1   10+ times a week             Never   15-30 minutes a day
# 2  6-10 times a week  3-5 times a week   30-60 minutes a day
# 3   10+ times a week  1-2 times a week   15-30 minutes a day
# 4   1-2 times a week  3-5 times a week  60-120 minutes a day
#
#          TimeAnswering                                   ProfessionalTech  \
# 0                  NaN                                                NaN
# 1  15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2  30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3  30-60 minutes a day  Automated testing;Continuous integration (CI) ...
# 4  30-60 minutes a day  Microservices;Automated testing;Observability ...
#
#                                             Industry           SurveyLength  \
# 0                                                NaN                    NaN
# 1  Information Services, IT, Software Development...  Appropriate in length
# 2  Information Services, IT, Software Development...  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                              Other  Appropriate in length
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                        Easy            285000.0
# 2                        Easy            250000.0
# 3                        Easy            156000.0
# 4  Neither easy nor difficult             23456.0
#
# [5 rows x 84 columns]

# %%
df.columns.values.tolist()
# Out:
# ['ResponseId',
#  'Q120',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'LearnCodeCoursesCert',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'TechList',
#  'BuyNewTool',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'OpSysPersonal use',
#  'OpSysProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
#  'OfficeStackSyncHaveWorkedWith',
#  'OfficeStackSyncWantToWorkWith',
#  'AISearchHaveWorkedWith',
#  'AISearchWantToWorkWith',
#  'AIDevHaveWorkedWith',
#  'AIDevWantToWorkWith',
#  'NEWSOSites',
#  'SOVisitFreq',
#  'SOAccount',
#  'SOPartFreq',
#  'SOComm',
#  'SOAI',
#  'AISelect',
#  'AISent',
#  'AIAcc',
#  'AIBen',
#  'AIToolInterested in Using',
#  'AIToolCurrently Using',
#  'AIToolNot interested in Using',
#  'AINextVery different',
#  'AINextNeither different nor similar',
#  'AINextSomewhat similar',
#  'AINextVery similar',
#  'AINextSomewhat different',
#  'TBranch',
#  'ICorPM',
#  'WorkExp',
#  'Knowledge_1',
#  'Knowledge_2',
#  'Knowledge_3',
#  'Knowledge_4',
#  'Knowledge_5',
#  'Knowledge_6',
#  'Knowledge_7',
#  'Knowledge_8',
#  'Frequency_1',
#  'Frequency_2',
#  'Frequency_3',
#  'TimeSearching',
#  'TimeAnswering',
#  'ProfessionalTech',
#  'Industry',
#  'SurveyLength',
#  'SurveyEase',
#  'ConvertedCompYearly']

# %%
df = df[['Country','ConvertedCompYearly','EdLevel','YearsCodePro','DevType']]
df = df.rename({'ConvertedCompYearly' : 'salary'}, axis = 1)
df.head()
# Out:
#                     Country    salary  \
# 0                       NaN       NaN
# 1  United States of America  285000.0
# 2  United States of America  250000.0
# 3  United States of America  156000.0
# 4               Philippines   23456.0
#
#                                         EdLevel YearsCodePro  \
# 0                                           NaN          NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)            9
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)           23
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)            7
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)            4
#
#                                 DevType
# 0                                   NaN
# 1  Senior Executive (C-Suite, VP, etc.)
# 2                   Developer, back-end
# 3                  Developer, front-end
# 4                 Developer, full-stack

# %%
df = df[df['salary'].notnull()]
df.head()
# Out:
#                                              Country    salary  \
# 1                           United States of America  285000.0
# 2                           United States of America  250000.0
# 3                           United States of America  156000.0
# 4                                        Philippines   23456.0
# 5  United Kingdom of Great Britain and Northern I...   96828.0
#
#                                              EdLevel YearsCodePro  \
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            9
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           23
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            7
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            4
# 5  Some college/university study without earning ...           21
#
#                                 DevType
# 1  Senior Executive (C-Suite, VP, etc.)
# 2                   Developer, back-end
# 3                  Developer, front-end
# 4                 Developer, full-stack
# 5                   Developer, back-end

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48019 entries, 1 to 89171
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       48019 non-null  object
#  1   salary        48019 non-null  float64
#  2   EdLevel       48019 non-null  object
#  3   YearsCodePro  47825 non-null  object
#  4   DevType       47904 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.2+ MB

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Country         0
# salary          0
# EdLevel         0
# YearsCodePro    0
# DevType         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47723 entries, 1 to 89171
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       47723 non-null  object
#  1   salary        47723 non-null  float64
#  2   EdLevel       47723 non-null  object
#  3   YearsCodePro  47723 non-null  object
#  4   DevType       47723 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# ###calculate contribution of each country to remove single row countries

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                11817
# Germany                                                  3944
# United Kingdom of Great Britain and Northern Ireland     3516
# Canada                                                   2094
# India                                                    1847
#                                                         ...
# Guyana                                                      1
# Guinea-Bissau                                               1
# Gabon                                                       1
# Tajikistan                                                  1
# Antigua and Barbuda                                         1
# Name: count, Length: 171, dtype: int64

# %% [markdown]
# Create function to remove single entries from country column

# %%
def Remove_singles(column_name, cutoff):
    country_dict = {}
    for i in range(len(column_name)):
        if column_name.values[i] >= cutoff:
            country_dict[column_name.index[i]] = column_name.index[i]
        else:
            country_dict[column_name.index[i]] = 'other'
    return country_dict

# %%
country_map = Remove_singles(df.Country.value_counts(),400)
df['Country'] = df['Country'].map(country_map)
df.Country.value_counts()
# Out:
# Country
# United States of America                                11817
# other                                                    8284
# Germany                                                  3944
# United Kingdom of Great Britain and Northern Ireland     3516
# Canada                                                   2094
# India                                                    1847
# France                                                   1788
# Netherlands                                              1357
# Poland                                                   1265
# Brazil                                                   1248
# Australia                                                1203
# Spain                                                    1139
# Sweden                                                   1053
# Italy                                                    1009
# Switzerland                                               656
# Austria                                                   531
# Denmark                                                   515
# Czech Republic                                            492
# Norway                                                    483
# Portugal                                                  477
# Israel                                                    469
# Belgium                                                   443
# Finland                                                   440
# Russian Federation                                        423
# Ukraine                                                   417
# New Zealand                                               410
# Romania                                                   403
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,1,figsize = (20, 20))
df.boxplot('salary','Country', ax=ax)
##plt.ylim()
plt.suptitle('Salary us$ vs country')
plt.title('')
plt.ylabel('salary')
plt.xticks(rotation = 90)
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lord\anaconda3\envs\adi\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\lord\anaconda3\envs\adi\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
sns.set_style("whitegrid")
##tips = sns.load_dataset("tips")
ax = sns.boxplot(x="Country", y="salary", data=df)
##plt.ylim(0, 50)
plt.show()

# %%
df['salary'].max()
# Out:
# 74351432.0

# %%
df = df[df['salary'] <= 5000000]
df = df[df['salary'] >=10000]
df = df[df['Country'] != 'other']

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
sns.set_style("whitegrid")
##tips = sns.load_dataset("tips")
ax = sns.boxplot(x="Country", y="salary", data=df)
##plt.ylim(0, 50)
plt.show()

# %%
df = df[df['salary'] <= 1000000]

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
sns.set_style("whitegrid")
##tips = sns.load_dataset("tips")
ax = sns.boxplot(x="Country", y="salary", data=df)
##plt.ylim(0, 50)
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (20, 20))
df.boxplot('salary','Country', ax=ax)
##plt.ylim()
plt.suptitle('Salary us$ vs country')
plt.title('')
plt.ylabel('salary')
plt.xticks(rotation = 90)
plt.show()

# %%
df = df[df['salary'] <= 500000]

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
sns.set_style("whitegrid")
##tips = sns.load_dataset("tips")
ax = sns.boxplot(x="Country", y="salary", data=df)
##plt.ylim(0, 50)
plt.show()

# %%
df = df[df['salary'] <= 300000]

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
sns.set_style("whitegrid")
##tips = sns.load_dataset("tips")
ax = sns.boxplot(x="Country", y="salary", data=df)
##plt.ylim(0, 50)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37119 entries, 1 to 89170
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       37119 non-null  object
#  1   salary        37119 non-null  float64
#  2   EdLevel       37119 non-null  object
#  3   YearsCodePro  37119 non-null  object
#  4   DevType       37119 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.7+ MB

# %%
df['YearsCodePro'].unique()
# Out:
# array(['9', '23', '7', '21', '3', '15', 'Less than 1 year', '10', '2',
#        '6', '14', '5', '19', '13', '16', '28', '30', '24', '40', '4',
#        '25', '12', '20', '11', '8', '18', '50', '27', '17', '43', '26',
#        '38', '33', '29', '22', '1', '31', '34', '37', '42',
#        'More than 50 years', '36', '39', '35', '41', '32', '44', '48',
#        '45', '46', '47', '49'], dtype=object)

# %%
def Clean_YearsCodePro(x):
    if x == 'Less than 1 year':
        return 0.5
    if x == 'More than 50 years':
        return 50
    return float(x)

df['YearsCodePro']=df['YearsCodePro'].apply(Clean_YearsCodePro)
df['YearsCodePro'].unique()
# Out:
# array([ 9. , 23. ,  7. , 21. ,  3. , 15. ,  0.5, 10. ,  2. ,  6. , 14. ,
#         5. , 19. , 13. , 16. , 28. , 30. , 24. , 40. ,  4. , 25. , 12. ,
#        20. , 11. ,  8. , 18. , 50. , 27. , 17. , 43. , 26. , 38. , 33. ,
#        29. , 22. ,  1. , 31. , 34. , 37. , 42. , 36. , 39. , 35. , 41. ,
#        32. , 44. , 48. , 45. , 46. , 47. , 49. ])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37119 entries, 1 to 89170
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       37119 non-null  object
#  1   salary        37119 non-null  float64
#  2   EdLevel       37119 non-null  object
#  3   YearsCodePro  37119 non-null  float64
#  4   DevType       37119 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
df.EdLevel.unique()
# Out:
# array(['Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Some college/university study without earning a degree',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Professional degree (JD, MD, Ph.D, Ed.D, etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Primary/elementary school', 'Something else'], dtype=object)

# %%
def Clean_Education(x):
    if "Bachelor’s degree" in x:
        return "Bachelor's degree"
    elif "Master’s degree" in x:
        return "Master's degree"
    elif "Professional degree" in x:
        return "Post grad"
    else:return "Less than Bachelor's"

df['EdLevel']=df['EdLevel'].apply(Clean_Education)
df.EdLevel.unique()
# Out:
# array(["Bachelor's degree", "Less than Bachelor's", "Master's degree",
#        'Post grad'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37119 entries, 1 to 89170
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       37119 non-null  object
#  1   salary        37119 non-null  float64
#  2   EdLevel       37119 non-null  object
#  3   YearsCodePro  37119 non-null  float64
#  4   DevType       37119 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                            13290
# Developer, back-end                               7245
# Developer, front-end                              2331
# Developer, desktop or enterprise applications     1955
# Other (please specify):                           1196
# Developer, mobile                                 1137
# Developer, embedded applications or devices       1105
# Engineering manager                               1055
# DevOps specialist                                  811
# Data scientist or machine learning specialist      768
# Engineer, data                                     731
# Research & Development role                        694
# Cloud infrastructure engineer                      636
# Senior Executive (C-Suite, VP, etc.)               573
# Academic researcher                                507
# Developer, game or graphics                        376
# Data or business analyst                           363
# Developer, QA or test                              265
# System administrator                               252
# Engineer, site reliability                         249
# Security professional                              196
# Project manager                                    185
# Scientist                                          171
# Product manager                                    167
# Developer Experience                               159
# Hardware Engineer                                  132
# Educator                                           125
# Blockchain                                         118
# Database administrator                             112
# Developer Advocate                                  90
# Designer                                            79
# Marketing or sales professional                     35
# Student                                             11
# Name: count, dtype: int64

# %%
def Clean_DevType(x):
    if x == "Data scientist or machine learning specialist":
        return "Data Scientist"
    elif x == "Engineer, data":
        return "Data Engineer"
    elif x == "Data or business analyst":
        return "Data Analyst"
    else:
        return "other"

# %%
df['DevType'] = df['DevType'].apply(Clean_DevType)

# %%
df.DevType.unique()
# Out:
# array(['other', 'Data Scientist', 'Data Analyst', 'Data Engineer'],
#       dtype=object)

# %%
df.DevType.value_counts()
# Out:
# DevType
# other             35257
# Data Scientist      768
# Data Engineer       731
# Data Analyst        363
# Name: count, dtype: int64

# %%
df = df[df['DevType'] != 'other']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1862 entries, 21 to 89071
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       1862 non-null   object
#  1   salary        1862 non-null   float64
#  2   EdLevel       1862 non-null   object
#  3   YearsCodePro  1862 non-null   float64
#  4   DevType       1862 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 87.3+ KB

# %%
df.DevType.value_counts()
# Out:
# DevType
# Data Scientist    768
# Data Engineer     731
# Data Analyst      363
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_education = LabelEncoder()
df['EdLevel'] = le_education.fit_transform(df['EdLevel']) 
df['EdLevel'].unique()
# Out:
# array([3, 0, 2, 1])

# %%
le_devtype = LabelEncoder()
df['DevType'] = le_devtype.fit_transform(df['DevType'])
df['DevType'].unique()
# Out:
# array([2, 0, 1])

# %%
le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])
df['Country'].unique()
# Out:
# array([ 9, 10, 25,  4, 13, 12, 22, 20,  8, 24, 16,  7,  2, 18,  0, 21,  1,
#         6,  3, 17, 11, 15, 14, 23, 19,  5])

# %%
x = df.drop('salary', axis = 1)
y = df['salary']

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg = LinearRegression()
linear_reg.fit(x,y.values)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
error = np.sqrt(mean_squared_error(y,y_pred))

# %%
error
# Out:
# 50684.00417680954

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree_reg = DecisionTreeRegressor(random_state = 0)
dec_tree_reg.fit(x,y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y,y_pred))
print("${:,.02f}".format(error))
# Out:
# $25,568.72

# %%
from sklearn.ensemble import RandomForestRegressor
ran_for_reg = RandomForestRegressor(random_state = 0)
ran_for_reg.fit(x,y.values)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = ran_for_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y,y_pred))
print("${:,.02f}".format(error))
# Out:
# $27,727.22

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None,2,4,6,8,10,12]
parameters = {"max_depth" : max_depth}

regressor = DecisionTreeRegressor(random_state = 0)
gs = GridSearchCV(regressor,parameters,scoring = 'neg_mean_squared_error')
gs.fit(x,y.values)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(x,y.values)
y_pred = regressor.predict(x)
error = np.sqrt(mean_squared_error(y,y_pred))
print("${:,.02f}".format(error))
# Out:
# $41,848.80

# %%
x
# Out:
#        Country  EdLevel  YearsCodePro  DevType
# 21           9        3           5.0        2
# 23           9        3          10.0        0
# 66          10        0           6.0        1
# 137         25        2           6.0        0
# 164          4        0           5.0        2
# ...        ...      ...           ...      ...
# 88818       25        2          10.0        1
# 88886       25        3           3.0        2
# 88986        0        0           9.0        1
# 89057       25        2           7.0        1
# 89071       25        2          38.0        0
#
# [1862 rows x 4 columns]

# %%
x = np.array([["United States of America", "Master's degree", 5, "Data Scientist" ]])
x
# Out:
# array([['United States of America', "Master's degree", '5',
#         'Data Scientist']], dtype='<U24')

# %%
x[:,0] = le_country.transform(x[:,0])
x[:,1] = le_education.transform(x[:,1])
x[:,3] = le_devtype.transform(x[:,3])
x = x.astype(float)
x
# Out:
# array([[25.,  2.,  5.,  2.]])

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# C:\Users\Lord\anaconda3\envs\adi\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([136469.8962963])

# %%
import pickle

# %%
data = {"model": regressor, "le_country": le_country , "le_education": le_education, "le_devtype": le_devtype}
with open('saved_steps.pkl', 'wb')as file:
    pickle.dump(data,file)

# %%
with open('saved_steps.pkl', 'rb')as file:
    data = pickle.load(file)

regressor_loaded = data["model"]
le_country = data["le_country"]
le_education = data["le_education"]
le_devtype = data["le_devtype"]

# %%
y_pred = regressor_loaded.predict(x)
y_pred
# Out:
# C:\Users\Lord\anaconda3\envs\adi\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([136469.8962963])
